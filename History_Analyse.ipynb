# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import openpyxl
#import seaborn as sns

# %%
import pandas as pd
history = pd.read_csv('hist/History_lumen_ResNet50_v2_23-02-2024_12-38-01.csv')
history.rename(columns={'Unnamed: 0': 'epoch'}, inplace=True)
history.head() # to display the first 5 lines of loaded data
# Out:
#    epoch      loss  accuracy  mean_iou  val_loss  val_accuracy  val_mean_iou
# 0      0  0.410812  0.853776  0.671301  3.589131      0.116347      0.057660
# 1      1  0.121584  0.970769  0.873234  3.287298      0.150621      0.078113
# 2      2  0.084376  0.974870  0.887972  1.330865      0.445663      0.258406
# 3      3  0.070731  0.977277  0.900085  0.743642      0.713867      0.488306
# 4      4  0.059666  0.980621  0.911098  0.510470      0.808694      0.587715

# %%
history.describe()
# Out:
#             epoch        loss    accuracy    mean_iou    val_loss  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000
# mean    49.500000    0.022561    0.991966    0.963769    0.132039
# std     29.011492    0.042670    0.014718    0.035925    0.500344
# min      0.000000    0.008166    0.853776    0.671301    0.020062
# 25%     24.750000    0.009703    0.992517    0.962759    0.026920
# 50%     49.500000    0.012881    0.995048    0.973952    0.033798
# 75%     74.250000    0.020813    0.996152    0.979518    0.046768
# max     99.000000    0.410812    0.996677    0.982042    3.589131
#
#        val_accuracy  val_mean_iou
# count    100.000000    100.000000
# mean       0.960073      0.897980
# std        0.134686      0.150057
# min        0.116347      0.057660
# 25%        0.986101      0.920645
# 50%        0.988853      0.931873
# 75%        0.990408      0.944427
# max        0.992466      0.961925

# %%
# summarize history for loss
plt.plot(history["loss"])
plt.plot(history["val_loss"])
plt.title("Model Loss")
plt.ylabel("loss")
plt.xlabel("epoch")
plt.legend(["Training", "Validation"], loc="upper right")
plt.show()

# summarize history for accuracy
plt.plot(history["accuracy"])
plt.plot(history["val_accuracy"])
plt.title("Model Accuracy")
plt.ylabel("accuracy")
plt.xlabel("epoch")
plt.legend(["Training", "Validation"], loc="lower right")
plt.show()


# summarize history for mean_iou
plt.plot(history["mean_iou"])
plt.plot(history["val_mean_iou"])
plt.title("model mean IoU")
plt.ylabel("mean IoU")
plt.xlabel("epoch")
plt.legend(["Training", "Validation"], loc="lower right")
plt.show()
